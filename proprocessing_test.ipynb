# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# name = '../behavior/behavior1/IMG/center_2017_12_16_11_42_44_965.jpg'
name = '../behavior/shadow.jpg'

plt.figure()
image = cv2.imread(name)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)

plt.figure()
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray, cmap="gray")

plt.figure()
image_eh = cv2.equalizeHist(image_gray)
plt.imshow(image_eh, cmap="gray")

plt.figure()
image_re = cv2.resize(image_gray, (64, 64), interpolation=cv2.INTER_AREA)
plt.imshow(image_re, cmap="gray")

# %%
# def preprocess_image(image):
        
image = cv2.imread(name)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.figure()
rows,cols,_ = image.shape
image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
# image = cv2.equalizeHist(image)
image = image[50:rows-20, 0:cols]
image = cv2.resize(image, (32, 32), interpolation=cv2.INTER_AREA)
image = image/255.0 - 0.5
plt.imshow(image, cmap="gray")

# %%
# Horizontal Flip
plt.figure()
image = cv2.imread(name)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_rgb = cv2.flip(image_rgb, 1)
plt.imshow(image_rgb)

# %%
# Horizontal transform
plt.figure()
tx = 150
ty = 0
image = cv2.imread(name)
rows,cols,_ = image.shape
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
M = np.float32([[1,0,tx],[0,1,ty]])
image_rgb = cv2.warpAffine(image_rgb,M,(cols,rows))
plt.imshow(image_rgb)


left_name = '../behavior/behavior1/IMG/left_2017_12_16_11_42_44_965.jpg'
plt.figure()
image = cv2.imread(left_name)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)

# %%
# brightness
plt.figure()
image = cv2.imread(name)
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
h, s, v = cv2.split(hsv)
final_hsv = cv2.merge((h, s, v))
image_hsv = cv2.cvtColor(final_hsv, cv2.COLOR_HSV2RGB)

plt.imshow(image_hsv)


plt.figure()
image = cv2.imread(name)
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
h, s, v = cv2.split(hsv)
print(v.dtype)
v = v.astype(np.float)
v -= 100
v[v<0] = 0
v = v.astype(np.uint8)
print(v.dtype)
final_hsv = cv2.merge((h, s, v))
image_hsv = cv2.cvtColor(final_hsv, cv2.COLOR_HSV2RGB)

plt.imshow(image_hsv)


plt.figure()
image = cv2.imread(name)
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
h, s, v = cv2.split(hsv)
print(v.dtype)
v = v.astype(np.float)
v += 50
v[v>255] = 255
v = v.astype(np.uint8)
print(v.dtype)
final_hsv = cv2.merge((h, s, v))
image_hsv = cv2.cvtColor(final_hsv, cv2.COLOR_HSV2RGB)

plt.imshow(image_hsv)
# Out:
# uint8
# uint8
# uint8
# uint8

# %%
plt.figure()
image = cv2.imread(name)
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
print(type(image))
h, s, v = cv2.split(hsv)
print(v.dtype)
v = v.astype(np.float)
v *= (np.random.uniform()+0.2)
v[v>255] = 255
v[v<0] = 0
v = v.astype(np.uint8)
print(v.dtype)
final_hsv = cv2.merge((h, s, v))
image_hsv = cv2.cvtColor(final_hsv, cv2.COLOR_HSV2RGB)

plt.imshow(image_hsv)
# Out:
# <class 'numpy.ndarray'>
# uint8
# uint8
